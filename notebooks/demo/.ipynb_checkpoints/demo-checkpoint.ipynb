# %%
import pandas as pd
import os
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = "C:\\Users\\nilss\\coding\\material\\ki_workshop\\data"
os.chdir(data_dir)

# %% [markdown]
# # Introducing MGH data
#
# [Olink MGH Intro](https://www.olink.com/mgh-covid-study/)
#
# [Olink MGH Overview](https://info.olink.com/mgh-covid-study-overview-page)
# - 384 patients
# - Clinical data
# - Protein data from Olink
#
#
# [Published Article](https://www.cell.com/action/showPdf?pii=S2666-3791%2821%2900115-4)
#
#
# We are combining OLINK & clinical data from Covid patients. Specifically, we are replicating figure B (page 5) from the published article
#
# ![...](https://raw.githubusercontent.com/NilsSkoglund/ki_workshop/main/data/olink_umap.png)

# %%
clinical = pd.read_csv('clinical_with_severity.csv')
olink = pd.read_csv('MGH_COVID_OLINK_NPX.csv')

# %% [markdown]
# ## First inspection clinical data

# %%
clinical
# Out:
#      subject_id  COVID  Age cat  BMI cat  HEART  LUNG  KIDNEY  DIABETES  HTN  \
# 0             1      1        1        4      0     0       0         0    0
# 1             2      1        2        2      0     0       0         0    0
# 2             3      1        3        4      0     1       0         0    0
# 3             4      1        1        2      0     0       0         0    0
# 4             5      1        3        3      0     0       0         1    1
# ..          ...    ...      ...      ...    ...   ...     ...       ...  ...
# 379         382      1        1        3      0     0       0         0    0
# 380         383      1        5        1      0     0       1         1    1
# 381         384      1        5        2      1     0       0         0    1
# 382         385      1        3        3      0     0       0         0    0
# 383         386      0        4        3      0     1       0         0    1
#
#      IMMUNO  ...  crp_3_cat  ddimer_3_cat  ldh_3_cat  abs_neut_7_cat  \
# 0         0  ...        1.0           1.0        1.0             NaN
# 1         0  ...        2.0           NaN        NaN             NaN
# 2         0  ...        3.0           2.0        3.0             NaN
# 3         0  ...        2.0           2.0        3.0             NaN
# 4         0  ...        5.0           3.0        NaN             3.0
# ..      ...  ...        ...           ...        ...             ...
# 379       0  ...        4.0           3.0        3.0             3.0
# 380       0  ...        NaN           5.0        3.0             5.0
# 381       0  ...        3.0           3.0        2.0             2.0
# 382       0  ...        2.0           2.0        2.0             NaN
# 383       0  ...        NaN           NaN        NaN             NaN
#
#      abs_lymph_7_cat  abs_mono_7_cat  creat_7_cat  crp_7_cat  ddimer_7_cat  \
# 0                NaN             NaN          NaN        NaN           NaN
# 1                NaN             NaN          NaN        NaN           NaN
# 2                NaN             NaN          NaN        NaN           NaN
# 3                NaN             NaN          NaN        NaN           NaN
# 4                5.0             3.0          1.0        4.0           4.0
# ..               ...             ...          ...        ...           ...
# 379              1.0             1.0          1.0        5.0           3.0
# 380              2.0             2.0          3.0        NaN           NaN
# 381              2.0             3.0          2.0        NaN           NaN
# 382              NaN             NaN          NaN        NaN           NaN
# 383              NaN             NaN          NaN        NaN           NaN
#
#      ldh_7_cat
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          3.0
# ..         ...
# 379        2.0
# 380        NaN
# 381        NaN
# 382        NaN
# 383        NaN
#
# [384 rows x 40 columns]

# %%
clinical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 40 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subject_id       384 non-null    int64
#  1   COVID            384 non-null    int64
#  2   Age cat          384 non-null    int64
#  3   BMI cat          384 non-null    int64
#  4   HEART            384 non-null    int64
#  5   LUNG             384 non-null    int64
#  6   KIDNEY           384 non-null    int64
#  7   DIABETES         384 non-null    int64
#  8   HTN              384 non-null    int64
#  9   IMMUNO           384 non-null    int64
#  10  Resp_Symp        384 non-null    int64
#  11  Fever_Sympt      384 non-null    int64
#  12  GI_Symp          384 non-null    int64
#  13  WHO 0            384 non-null    int64
#  14  WHO 3            384 non-null    int64
#  15  WHO 7            384 non-null    int64
#  16  WHO 28           384 non-null    int64
#  17  WHO max          384 non-null    int64
#  18  abs_neut_0_cat   380 non-null    float64
#  19  abs_lymph_0_cat  379 non-null    float64
#  20  abs_mono_0_cat   376 non-null    float64
#  21  creat_0_cat      381 non-null    float64
#  22  crp_0_cat        366 non-null    float64
#  23  ddimer_0_cat     358 non-null    float64
#  24  ldh_0_cat        362 non-null    float64
#  25  Trop_72h         384 non-null    int64
#  26  abs_neut_3_cat   278 non-null    float64
#  27  abs_lymph_3_cat  277 non-null    float64
#  28  abs_mono_3_cat   274 non-null    float64
#  29  creat_3_cat      279 non-null    float64
#  30  crp_3_cat        228 non-null    float64
#  31  ddimer_3_cat     209 non-null    float64
#  32  ldh_3_cat        193 non-null    float64
#  33  abs_neut_7_cat   179 non-null    float64
#  34  abs_lymph_7_cat  178 non-null    float64
#  35  abs_mono_7_cat   178 non-null    float64
#  36  creat_7_cat      191 non-null    float64
#  37  crp_7_cat        144 non-null    float64
#  38  ddimer_7_cat     133 non-null    float64
#  39  ldh_7_cat        115 non-null    float64
# dtypes: float64(21), int64(19)
# memory usage: 120.1 KB

# %%
clinical.COVID.value_counts()
# Out:
# 1    306
# 0     78
# Name: COVID, dtype: int64

# %%
clinical.HEART.value_counts()
# Out:
# 0    313
# 1     71
# Name: HEART, dtype: int64

# %%
sns.countplot(data=clinical, x="Age cat", hue="COVID")
# Out:
# <AxesSubplot:xlabel='Age cat', ylabel='count'>

# %%
sns.heatmap(clinical.corr())
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style="white")

# Compute the correlation matrix
corr = clinical.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Olink data | First inspection!

# %%
olink
# Out:
#                     SampleID  subject_id Timepoint   OlinkID UniProt  \
# 0                       1_D0         1.0        D0  OID21311  Q9BTE6
# 1                       1_D0         1.0        D0  OID20921  Q96IU4
# 2                       1_D0         1.0        D0  OID21280  P00519
# 3                       1_D0         1.0        D0  OID21269  P09110
# 4                       1_D0         1.0        D0  OID20159  P16112
# ...                      ...         ...       ...       ...     ...
# 1148911  CONTROL_SAMPLE_AS-2         NaN       NaN  OID20082  Q13105
# 1148912  CONTROL_SAMPLE_AS-2         NaN       NaN  OID20082  Q13105
# 1148913  CONTROL_SAMPLE_AS-2         NaN       NaN  OID20082  Q13105
# 1148914  CONTROL_SAMPLE_AS-2         NaN       NaN  OID20082  Q13105
# 1148915  CONTROL_SAMPLE_AS-2         NaN       NaN  OID20082  Q13105
#
#                    Panel                     PlateID     LOD     NPX
# 0               ONCOLOGY   20200772_Plate5_NEURO_ONC  0.7204  3.2277
# 1              NEUROLOGY   20200772_Plate5_NEURO_ONC  0.5696  0.7205
# 2               ONCOLOGY   20200772_Plate5_NEURO_ONC  0.5313  2.6293
# 3               ONCOLOGY   20200772_Plate5_NEURO_ONC  2.0588  3.2670
# 4        CARDIOMETABOLIC  20200772_Plate5_CARDIO_INF  1.1623  2.0308
# ...                  ...                         ...     ...     ...
# 1148911  CARDIOMETABOLIC  20200772_plate7_CARDIO_INF  0.5020  1.0699
# 1148912  CARDIOMETABOLIC  20200772_PLATE3_CARDIO_INF  0.5020  1.0344
# 1148913  CARDIOMETABOLIC     20200772_Plate9_CAR_INF  0.5020  1.2529
# 1148914  CARDIOMETABOLIC  20200772_Plate5_CARDIO_INF  0.5020  1.1065
# 1148915  CARDIOMETABOLIC  20200772_plate8_CARDIO_INF  0.5020  1.1759
#
# [1148916 rows x 9 columns]

# %%
olink = olink[["SampleID", "UniProt", "NPX"]]
olink
# Out:
#                     SampleID UniProt     NPX
# 0                       1_D0  Q9BTE6  3.2277
# 1                       1_D0  Q96IU4  0.7205
# 2                       1_D0  P00519  2.6293
# 3                       1_D0  P09110  3.2670
# 4                       1_D0  P16112  2.0308
# ...                      ...     ...     ...
# 1148911  CONTROL_SAMPLE_AS-2  Q13105  1.0699
# 1148912  CONTROL_SAMPLE_AS-2  Q13105  1.0344
# 1148913  CONTROL_SAMPLE_AS-2  Q13105  1.2529
# 1148914  CONTROL_SAMPLE_AS-2  Q13105  1.1065
# 1148915  CONTROL_SAMPLE_AS-2  Q13105  1.1759
#
# [1148916 rows x 3 columns]

# %%
# 1429 different UniProt with NPX values per SampleId
olink.UniProt.nunique()
# Out:
# 1420

# %%
olink.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148916 entries, 0 to 1148915
# Data columns (total 3 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   SampleID  1148916 non-null  object
#  1   UniProt   1148916 non-null  object
#  2   NPX       1148898 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 26.3+ MB

# %%
# 18 values missing for NPX
olink.isna().value_counts()
# Out:
# SampleID  UniProt  NPX
# False     False    False    1148898
#                    True          18
# dtype: int64

# %% [markdown]
# ## preprocessing OLINK data

# %%
# reshaping

# %%
olink_reshaped = olink.pivot_table(columns = "UniProt", index = "SampleID", values = "NPX")
olink_reshaped
# Out:
# UniProt                A1L4H1    A4D1B5    A6NI73    B1AKI9  NTproBNP  \
# SampleID
# 100_D0               2.698300 -1.493100  4.512300  3.245600 -0.351600
# 100_D3               2.714700 -1.259300  4.363800  3.374800  0.131000
# 101_D0               2.959400 -0.919600  4.542400  2.631200  0.384200
# 101_D3               2.430000 -1.380700  3.829500  2.609600  1.846700
# 101_D7               3.146300 -0.079700  4.113900  2.148600  1.775700
# ...                       ...       ...       ...       ...       ...
# 99_D3                2.563400 -1.393000  4.587300  3.161500  1.306800
# 9_D0                 2.100800 -0.769000  4.244400  4.202800  4.548400
# 9_D3                 2.267700 -1.213200  4.154900  3.317300  4.044000
# CONTROL_SAMPLE_AS-1  4.683092  2.159692  5.529038  5.646331  2.203492
# CONTROL_SAMPLE_AS-2  4.602557  2.195571  5.327586  5.406986  1.923614
#
# UniProt                O00161    O00175    O00182    O00186    O00214  ...  \
# SampleID                                                               ...
# 100_D0               4.992800  2.558400  8.319100  0.341000  4.250400  ...
# 100_D3               2.773800  3.532000  8.364800 -0.124700  3.758600  ...
# 101_D0               3.632700  3.872800  8.163800  0.456700  3.395000  ...
# 101_D3               1.526500  3.983200  7.795700 -0.020400  2.796200  ...
# 101_D7               9.250600  6.062200  8.690200  5.012900  8.757300  ...
# ...                       ...       ...       ...       ...       ...  ...
# 99_D3                3.652200  5.698500  8.901700  0.141600  2.808900  ...
# 9_D0                 4.272900  7.346500  9.372400  0.292900  3.856400  ...
# 9_D3                 4.376700  7.420300  8.785900  0.069200  3.526900  ...
# CONTROL_SAMPLE_AS-1  2.017808  7.902285  8.151238 -0.140246  3.949500  ...
# CONTROL_SAMPLE_AS-2  1.854629  7.689443  8.120700 -0.231943  3.964886  ...
#
# UniProt                Q9Y639    Q9Y653    Q9Y662    Q9Y680    Q9Y6A5  \
# SampleID
# 100_D0              -0.239800  2.161200  3.702300  0.875000  1.318100
# 100_D3              -1.170300  1.470800  3.310500  0.217100 -0.302900
# 101_D0              -0.020300  2.845400  2.900000  1.991200  0.505600
# 101_D3              -0.085200  1.695900  2.202700 -0.412800 -0.100900
# 101_D7               0.242100  2.491400  2.124200  2.528200  6.404600
# ...                       ...       ...       ...       ...       ...
# 99_D3                0.361100  1.923700  2.742100  0.121900  0.751200
# 9_D0                -0.346800  3.592100  2.494800  0.242100  0.276800
# 9_D3                -0.591600  3.301500  2.139800  0.460800  0.523000
# CONTROL_SAMPLE_AS-1  1.064646  5.324523  3.733908  3.621992 -0.244385
# CONTROL_SAMPLE_AS-2  1.155143  5.041071  3.584429  3.692343 -0.461186
#
# UniProt                Q9Y6D9    Q9Y6K9    Q9Y6N7    Q9Y6Q6    Q9Y6Y9
# SampleID
# 100_D0               3.350200  5.759200  4.308400  5.203500  0.276900
# 100_D3               3.218200  3.297200  4.269600  5.362400  0.536900
# 101_D0               3.164700  4.075000  3.772400  4.391400  0.717500
# 101_D3               2.678700  2.170000  3.505200  4.346900  0.513600
# 101_D7               3.899100  9.188100  4.080100  5.133900  0.463000
# ...                       ...       ...       ...       ...       ...
# 99_D3                4.012300  4.214400  3.867400  6.201700  0.310200
# 9_D0                 4.623800  4.518500  3.723900  6.740600  1.405800
# 9_D3                 3.631400  4.362800  3.584700  6.117100  1.521500
# CONTROL_SAMPLE_AS-1  2.450946  2.033438  6.143308  6.739915  2.022162
# CONTROL_SAMPLE_AS-2  2.358257  1.718286  6.015714  6.761700  1.859971
#
# [786 rows x 1420 columns]

# %%
olink_reshaped.isna().sum().sum()
# Out:
# 18

# %%
# imputing for missing values
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy="mean")
olink_reshaped[:] = imputer.fit_transform(olink_reshaped)

# %%
olink_reshaped.isna().sum().sum()
# Out:
# 0

# %%
# scaling
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
olink_reshaped[:] = scaler.fit_transform(olink_reshaped)

# %%
# truncating outliers
    # truncating z-scores at +-4 (following the study)

# %%
def trunc_4(x):
    if x > 4:
        return 4
    elif x < -4:
        return -4
    else:
        return x

# %%
olink_reshaped = olink_reshaped.applymap(trunc_4)

# %% [markdown]
# ## Clinical data | First inspection

# %%
clinical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 41 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subject_id       384 non-null    int64
#  1   COVID            384 non-null    int64
#  2   Age cat          384 non-null    int64
#  3   BMI cat          384 non-null    int64
#  4   HEART            384 non-null    int64
#  5   LUNG             384 non-null    int64
#  6   KIDNEY           384 non-null    int64
#  7   DIABETES         384 non-null    int64
#  8   HTN              384 non-null    int64
#  9   IMMUNO           384 non-null    int64
#  10  Resp_Symp        384 non-null    int64
#  11  Fever_Sympt      384 non-null    int64
#  12  GI_Symp          384 non-null    int64
#  13  WHO 0            384 non-null    int64
#  14  WHO 3            384 non-null    int64
#  15  WHO 7            384 non-null    int64
#  16  WHO 28           384 non-null    int64
#  17  WHO max          384 non-null    int64
#  18  abs_neut_0_cat   380 non-null    float64
#  19  abs_lymph_0_cat  379 non-null    float64
#  20  abs_mono_0_cat   376 non-null    float64
#  21  creat_0_cat      381 non-null    float64
#  22  crp_0_cat        366 non-null    float64
#  23  ddimer_0_cat     358 non-null    float64
#  24  ldh_0_cat        362 non-null    float64
#  25  Trop_72h         384 non-null    int64
#  26  abs_neut_3_cat   278 non-null    float64
#  27  abs_lymph_3_cat  277 non-null    float64
#  28  abs_mono_3_cat   274 non-null    float64
#  29  creat_3_cat      279 non-null    float64
#  30  crp_3_cat        228 non-null    float64
#  31  ddimer_3_cat     209 non-null    float64
#  32  ldh_3_cat        193 non-null    float64
#  33  abs_neut_7_cat   179 non-null    float64
#  34  abs_lymph_7_cat  178 non-null    float64
#  35  abs_mono_7_cat   178 non-null    float64
#  36  creat_7_cat      191 non-null    float64
#  37  crp_7_cat        144 non-null    float64
#  38  ddimer_7_cat     133 non-null    float64
#  39  ldh_7_cat        115 non-null    float64
#  40  Severity         384 non-null    object
# dtypes: float64(21), int64(19), object(1)
# memory usage: 123.1+ KB

# %%
clinical.head(3)
# Out:
#    subject_id  COVID  Age cat  BMI cat  HEART  LUNG  KIDNEY  DIABETES  HTN  \
# 0           1      1        1        4      0     0       0         0    0
# 1           2      1        2        2      0     0       0         0    0
# 2           3      1        3        4      0     1       0         0    0
#
#    IMMUNO  ...  ddimer_3_cat  ldh_3_cat  abs_neut_7_cat  abs_lymph_7_cat  \
# 0       0  ...           1.0        1.0             NaN              NaN
# 1       0  ...           NaN        NaN             NaN              NaN
# 2       0  ...           2.0        3.0             NaN              NaN
#
#    abs_mono_7_cat  creat_7_cat  crp_7_cat  ddimer_7_cat  ldh_7_cat    Severity
# 0             NaN          NaN        NaN           NaN        NaN  Non-severe
# 1             NaN          NaN        NaN           NaN        NaN  Non-severe
# 2             NaN          NaN        NaN           NaN        NaN  Non-severe
#
# [3 rows x 41 columns]

# %%
clinical.size
# Out:
# 15744

# %% [markdown]
# ### Heatmap of correlations

# %%
clinical.corr()
# Out:
#                  subject_id     COVID   Age cat   BMI cat     HEART      LUNG  \
# subject_id         1.000000  0.015351  0.036063 -0.101286 -0.008801  0.097148
# COVID              0.015351  1.000000 -0.128578  0.170967 -0.143026 -0.267415
# Age cat            0.036063 -0.128578  1.000000 -0.293622  0.319908  0.168288
# HEART                  0.076660     0.008991   0.058991     -0.034292
# LUNG                   0.061248     0.030501  -0.003095     -0.200818
# KIDNEY                -0.135771     0.456017   0.056432      0.046493
# DIABETES               0.239585     0.273049   0.125154      0.132350
# HTN                   -0.016663     0.258759   0.143587      0.003935
# IMMUNO                 0.064621     0.009626  -0.064749      0.032918
# Resp_Symp              0.011307     0.038786   0.002131     -0.051512
# Fever_Sympt            0.002091    -0.080946  -0.097553      0.070862
# GI_Symp                0.008030    -0.074117   0.058752     -0.020182
# WHO 0                 -0.232105    -0.189274  -0.403492     -0.443663
# WHO 3                 -0.198616    -0.118200  -0.449253     -0.441582
# WHO 7                 -0.168179    -0.271451  -0.601073     -0.401065
# WHO 28                -0.089855    -0.361429  -0.560164     -0.265936
# WHO max               -0.184897    -0.237617  -0.578816     -0.397144
# abs_neut_0_cat         0.295739     0.078674   0.070776      0.224683
# abs_lymph_0_cat        0.224995    -0.157265  -0.241550     -0.107439
# abs_mono_0_cat         0.249206     0.014614  -0.049804     -0.042606
# creat_0_cat           -0.114794     0.565671   0.076458      0.073571
# crp_0_cat             -0.004229    -0.042519   0.134899      0.329740
# ddimer_0_cat          -0.014332     0.047411   0.044386      0.453630
# ldh_0_cat              0.130852     0.031991   0.125934      0.364434
# Trop_72h              -0.110552     0.090732   0.012885      0.116008
# abs_neut_3_cat         0.324024     0.106052   0.323006      0.234246
# abs_lymph_3_cat        0.229412    -0.008836  -0.205090     -0.085612
# abs_mono_3_cat         0.413416     0.214443  -0.091380     -0.018541
# creat_3_cat            0.095777     0.843876   0.244133      0.178347
# crp_3_cat              0.135485     0.146126   0.446783      0.249315
# ddimer_3_cat           0.036480     0.190699   0.178136      0.604646
# ldh_3_cat              0.114818     0.281053   0.309726      0.304491
# abs_neut_7_cat         0.471474     0.230324   0.436793      0.384678
# abs_lymph_7_cat        0.255930    -0.202339  -0.375701     -0.147867
# abs_mono_7_cat         1.000000     0.155858   0.128998      0.190737
# creat_7_cat            0.155858     1.000000   0.243798      0.257225
# crp_7_cat              0.128998     0.243798   1.000000      0.368274
# ddimer_7_cat           0.190737     0.257225   0.368274      1.000000
# ldh_7_cat              0.024630     0.179724   0.235363      0.378176
#
#                  ldh_7_cat
# subject_id       -0.052894
# COVID             0.161656
# Age cat          -0.090736
# BMI cat           0.016407
# HEART            -0.052587
# LUNG             -0.132021
# KIDNEY           -0.157354
# DIABETES         -0.067249
# HTN               0.024108
# IMMUNO           -0.143122
# Resp_Symp         0.240698
# Fever_Sympt       0.060648
# GI_Symp           0.059945
# WHO 0            -0.207283
# WHO 3            -0.214245
# WHO 7            -0.271136
# WHO 28           -0.201387
# WHO max          -0.257203
# abs_neut_0_cat    0.007157
# abs_lymph_0_cat   0.024617
# abs_mono_0_cat   -0.003397
# creat_0_cat      -0.014841
# crp_0_cat         0.106810
# ddimer_0_cat      0.108048
# ldh_0_cat         0.385768
# Trop_72h         -0.013195
# abs_neut_3_cat    0.131437
# abs_lymph_3_cat   0.024547
# abs_mono_3_cat   -0.217409
# creat_3_cat       0.135817
# crp_3_cat         0.209437
# ddimer_3_cat      0.242564
# ldh_3_cat         0.651122
# abs_neut_7_cat    0.266122
# abs_lymph_7_cat   0.035163
# abs_mono_7_cat    0.024630
# creat_7_cat       0.179724
# crp_7_cat         0.235363
# ddimer_7_cat      0.378176
# ldh_7_cat         1.000000
#
# [40 rows x 40 columns]

# %%
import seaborn as sns

# %%
sns.heatmap(clinical.corr())

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(clinical.corr())
plt.title("Hello", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Hello')

# %% [markdown]
# ### Better looking heatmap | Copy & Paste!
#
# google seaborn > gallery > heatmap at 4th row
#
# https://seaborn.pydata.org/examples/many_pairwise_correlations.html

# %%
import numpy as np

# %%
sns.set_theme(style="white")

# Compute the correlation matrix
corr = clinical.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Olink data | First inspection!

# %%
olink = olink[["SampleID", "UniProt", "NPX"]]

# %%
olink
# Out:
#         SampleID UniProt     NPX
# 0           1_D0  Q9BTE6  3.2277
# 1           1_D0  Q96IU4  0.7205
# 2           1_D0  P00519  2.6293
# 3           1_D0  P09110  3.2670
# 4           1_D0  P16112  2.0308
# ...          ...     ...     ...
# 1113275    99_D3  O43895  2.5027
# 1113276    99_D3  P07947  3.7681
# 1113277    99_D3  Q7Z739  0.9126
# 1113278    99_D3  Q05516  1.8974
# 1113279    99_D3  Q13105  2.0095
#
# [1113280 rows x 3 columns]

# %%
# reshaping

# %%
example = olink.loc[olink["SampleID"] == "1_D0"]

# %%
example
# Out:
#      SampleID UniProt     NPX
# 0        1_D0  Q9BTE6  3.2277
# 1        1_D0  Q96IU4  0.7205
# 2        1_D0  P00519  2.6293
# 3        1_D0  P09110  3.2670
# 4        1_D0  P16112  2.0308
# ...       ...     ...     ...
# 1415     1_D0  O43895  4.8863
# 1416     1_D0  P07947  4.9975
# 1417     1_D0  Q7Z739  0.9208
# 1418     1_D0  Q05516  1.2148
# 1419     1_D0  Q13105  0.4649
#
# [1420 rows x 3 columns]

# %%
olink_reshaped = olink.pivot_table(columns = "UniProt", index = "SampleID", values = "NPX")

# %% [markdown]
# ### Preprocessing

# %%
# imputing

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy="mean")

# %%
imputer.fit_transform(olink_reshaped)
# Out:
# array([[ 2.6983, -1.4931,  4.5123, ...,  4.3084,  5.2035,  0.2769],
#        [ 2.7147, -1.2593,  4.3638, ...,  4.2696,  5.3624,  0.5369],
#        [ 2.9594, -0.9196,  4.5424, ...,  3.7724,  4.3914,  0.7175],
#        ...,
#        [ 2.5634, -1.393 ,  4.5873, ...,  3.8674,  6.2017,  0.3102],
#        [ 2.1008, -0.769 ,  4.2444, ...,  3.7239,  6.7406,  1.4058],
#        [ 2.2677, -1.2132,  4.1549, ...,  3.5847,  6.1171,  1.5215]])

# %%
olink_reshaped[:] = imputer.fit_transform(olink_reshaped)

# %%
# scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
olink_reshaped[:] = scaler.fit_transform(olink_reshaped)

# %%
# Last preprocessing step!: 
    # truncating z-scores at +-4 (sort of following the study)

# %%
def trunc_4(x):
    if x > 4:
        return 4
    elif x < -4:
        return -4
    else:
        return x

# %%
olink_reshaped = olink_reshaped.applymap(trunc_4)

# %%
# We are now happy with our reshaping & preprocessing

# %%
olink_reshaped.to_csv("olink_reshaped.csv")

# %% [markdown]
# ## UMAP on Olink Data

# %%
#!pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ---------------------------------------- 88.2/88.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.17 in c:\users\nilss\anaconda3\lib\site-packages (from umap-learn) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\nilss\anaconda3\lib\site-packages (from umap-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\nilss\anaconda3\lib\site-packages (from umap-learn) (1.9.1)
# Requirement already satisfied: numba>=0.49 in c:\users\nilss\anaconda3\lib\site-packages (from umap-learn) (0.55.1)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm in c:\users\nilss\anaconda3\lib\site-packages (from umap-learn) (4.64.1)
# Requirement already satisfied: setuptools in c:\users\nilss\anaconda3\lib\site-packages (from numba>=0.49->umap-learn) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\nilss\anaconda3\lib\site-packages (from numba>=0.49->umap-learn) (0.38.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\nilss\anaconda3\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nilss\anaconda3\lib\site-packages (from scikit-learn>=0.22->umap-learn) (2.2.0)
# Requirement already satisfied: colorama in c:\users\nilss\anaconda3\lib\site-packages (from tqdm->umap-learn) (0.4.5)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py): started
#   Building wheel for umap-learn (setup.py): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82814 sha256=616ff1392ca75feeaa4db89b439292e1ed987bea88157ee622987df3481b9622
#   Stored in directory: c:\users\nilss\appdata\local\pip\cache\wheels\f4\3e\1c\596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py): started
#   Building wheel for pynndescent (setup.py): finished with status 'done'
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55496 sha256=16b6cdbc56d641936db2bad2c793cd58a791998ed70b6fcb27c20f3d66e2bfbc
#   Stored in directory: c:\users\nilss\appdata\local\pip\cache\wheels\b9\89\cc\59ab91ef5b21dc2ab3635528d7d227f49dfc9169905dcb959d
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.8 umap-learn-0.5.3

# %%
import umap

# %%
olink_reshaped.shape
# Out:
# (786, 1420)

# %%
reducer = umap.UMAP(random_state = 1)
embedding = reducer.fit_transform(olink_reshaped)
embedding = pd.DataFrame(embedding)

embedding.head()
# Out:
#            0          1
# 0  10.218000   8.821906
# 1  10.987122   5.611681
# 2  11.623988   7.106500
# 3  12.011353   5.986228
# 4   7.504181  10.579615

# %%
sns.scatterplot(data = embedding, x = 0, y = 1)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %% [markdown]
# ## adding in clinical data

# %%
olink_reshaped.head()
# Out:
# UniProt     A1L4H1    A4D1B5    A6NI73    B1AKI9  NTproBNP    O00161  \
# SampleID
# 100_D0   -0.796242 -0.625723 -0.071854 -0.511760 -1.112518  0.342816
# 100_D3   -0.767985 -0.174917 -0.321324 -0.338004 -0.888906 -0.868491
# 101_D0   -0.346365  0.480082 -0.021288 -1.338046 -0.771587 -0.399635
# 101_D3   -1.258525 -0.408997 -1.218914 -1.367095 -0.093941 -1.549367
# 101_D7   -0.024334  2.099552 -0.741140 -1.987078 -0.126839  2.667062
#
# UniProt     O00175    O00182    O00186    O00214  ...    Q9Y639    Q9Y653  \
# SampleID                                          ...
# 100_D0   -1.993294 -0.188790 -0.245793  0.474331  ... -0.800778 -0.953806
# 100_D3   -1.315763 -0.129362 -0.972447 -0.055888  ... -1.837377 -1.481694
# 101_D0   -1.078600 -0.390742 -0.065261 -0.447891  ... -0.556250 -0.430658
# 101_D3   -1.001772 -0.869418 -0.809703 -1.093468  ... -0.628550 -1.309580
# 101_D7    0.445009  0.293787  4.000000  4.000000  ... -0.263930 -0.701331
#
# UniProt     Q9Y662    Q9Y680    Q9Y6A5    Q9Y6D9    Q9Y6K9    Q9Y6N7  \
# SampleID
# 100_D0    1.440644  0.742490  0.153462 -0.216829  0.669629  0.296652
# 100_D3    0.872106 -0.508623 -1.418106 -0.337452 -0.872329  0.217806
# 101_D0    0.276432  2.865142 -0.634261 -0.386340 -0.385191 -0.792563
# 101_D3   -0.735415 -1.706490 -1.222266 -0.830450 -1.578297 -1.335544
# 101_D7   -0.849326  3.886342  4.000000  0.284759  2.817158 -0.167280
#
# UniProt     Q9Y6Q6    Q9Y6Y9
# SampleID
# 100_D0   -0.511349 -1.363434
# 100_D3   -0.385778 -0.908921
# 101_D0   -1.153115 -0.593209
# 101_D3   -1.188281 -0.949652
# 101_D7   -0.566351 -1.038108
#
# [5 rows x 1420 columns]

# %%
# add in sample id (from olink_reshaped index column)
embedding["SampleId"] = olink_reshaped.index

# %%
# drop control samples
embedding = embedding.loc[~embedding["SampleId"].str.contains("CONTROL")]

# %%
# enable join with clinical data
    # extract subject_id from SampleId
    # convert to int
embedding["subject_id"] = embedding.SampleId.str.extract(r"([0-9]+)")[0]
embedding["subject_id"] = embedding["subject_id"].astype(int)
embedding.head()
# Out:
#            0          1 SampleId  subject_id
# 0  10.218000   8.821906   100_D0         100
# 1  10.987122   5.611681   100_D3         100
# 2  11.623988   7.106500   101_D0         101
# 3  12.011353   5.986228   101_D3         101
# 4   7.504181  10.579615   101_D7         101

# %%
final_df = embedding.merge(clinical, on="subject_id")
final_df.head()
# Out:
#            0         1 SampleId  subject_id  COVID  Age cat  BMI cat  HEART  \
# 0  10.218000  8.821906   100_D0         100      1        1        4      0
# 1  10.218000  8.821906   100_D0         100      1        1        4      0
# 2  10.987122  5.611681   100_D3         100      1        1        4      0
# 3  10.987122  5.611681   100_D3         100      1        1        4      0
# 4  11.623988  7.106500   101_D0         101      1        2        1      0
#
#    LUNG  KIDNEY  ...  ddimer_3_cat  ldh_3_cat  abs_neut_7_cat  \
# 0     0       0  ...           4.0        3.0             NaN
# 1     0       0  ...           4.0        3.0             NaN
# 2     0       0  ...           4.0        3.0             NaN
# 3     0       0  ...           4.0        3.0             NaN
# 4     0       0  ...           2.0        3.0             2.0
#
#    abs_lymph_7_cat  abs_mono_7_cat  creat_7_cat  crp_7_cat  ddimer_7_cat  \
# 0              NaN             NaN          NaN        NaN           NaN
# 1              NaN             NaN          NaN        NaN           NaN
# 2              NaN             NaN          NaN        NaN           NaN
# 3              NaN             NaN          NaN        NaN           NaN
# 4              4.0             3.0          2.0        1.0           2.0
#
#    ldh_7_cat    Severity
# 0        NaN  Non-severe
# 1        NaN  Non-severe
# 2        NaN  Non-severe
# 3        NaN  Non-severe
# 4        3.0  Non-severe
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Final vizualizations, UMAP combined with clinical data

# %%
sns.scatterplot(data = final_df, x = 0, y = 1, hue = "Age cat", palette = "mako")
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
sns.scatterplot(data = final_df, x = 0, y = 1, hue = "Severity", palette = "RdPu")
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>
